# %% [markdown]
# # Data Cleaning & Wrangling
# ## Location Data

# %%
import pandas as pd

# Loading the data
toilet_df = pd.read_csv("toiletmapexport_250301_074429.csv")

toilet_df.head(5)
# Out:
#    FacilityID                                  URL                  Name  \
# 0           1  https://toiletmap.gov.au/facility/1   Sandy Beach Reserve
# 1           2  https://toiletmap.gov.au/facility/2         Point Reserve
# 2           3  https://toiletmap.gov.au/facility/3  Success Hill Reserve
# 3           4  https://toiletmap.gov.au/facility/4       Jubilee Reserve
# 4           5  https://toiletmap.gov.au/facility/5      Ashfield Reserve
#
#       FacilityType                    Address1        Town State AddressNote  \
# 0  Park or reserve       Lost 15525, West Road  Bassendean    WA         NaN
# 1  Park or reserve         Lot 197, North Road  Bassendean    WA         NaN
# 2  Park or reserve    Lot 2838, Seventh Avenue  Bassendean    WA         NaN
# 3  Park or reserve     Lot 6322, Robinson Road   Eden Hill    WA         NaN
# 4  Park or reserve  Lot 12061, 2 Coulston Road    Ashfield    WA         NaN
#
#     Latitude   Longitude  ...  Ambulant  Accessible LHTransfer  RHTransfer  \
# 0 -31.921836  115.950206  ...     False        True      False       False
# 1 -31.904410  115.960991  ...     False        True      False       False
# 2 -31.896289  115.955781  ...     False        True      False       False
# 3 -31.891474  115.940164  ...     False       False      False       False
# 4 -31.913433  115.936477  ...     False        True      False       False
#
#    ToiletNote  SharpsDisposal  DrinkingWater SanitaryDisposal  \
# 0         NaN            True           True             True
# 1         NaN            True           True             True
# 2         NaN            True           True             True
# 3         NaN            True          False             True
# 4         NaN            True           True             True
#
#    MensPadDisposal  Shower
# 0            False   False
# 1            False   False
# 2            False    True
# 3            False   False
# 4            False   False
#
# [5 rows x 47 columns]

# %%
toilet_df.columns = toilet_df.columns.str.lower()

toilet_df.columns
# Out:
# Index(['facilityid', 'url', 'name', 'facilitytype', 'address1', 'town',
#        'state', 'addressnote', 'latitude', 'longitude', 'parking',
#        'parkingaccessible', 'parkingnote', 'keyrequired', 'mlak24',
#        'mlakafterhours', 'paymentrequired', 'accessnote', 'adultchange',
#        'changingplaces', 'byosling', 'acshower', 'acmlak', 'adultchangenote',
#        'babychange', 'babycareroom', 'babychangenote', 'dumppoint',
#        'dpwashout', 'dpafterhours', 'dumppointnote', 'openinghours',
#        'openinghoursnote', 'male', 'female', 'unisex', 'allgender', 'ambulant',
#        'accessible', 'lhtransfer', 'rhtransfer', 'toiletnote',
#        'sharpsdisposal', 'drinkingwater', 'sanitarydisposal',
#        'menspaddisposal', 'shower'],
#       dtype='object')

# %%
# Extracting needed columns
toilet_df = toilet_df[['facilityid', 'name', 'facilitytype', 'address1', 'town', 'state',
                      'latitude', 'longitude', 'parkingaccessible', 'male', 'female',
                      'unisex', 'allgender', 'accessible', 'paymentrequired', 'babychange']]

# %%
# Rounding latitude and longitude to 6 decimal places
toilet_df['latitude'] = toilet_df['latitude'].round(6)
toilet_df['longitude'] = toilet_df['longitude'].round(6)

toilet_df.head(5)
# Out:
#    facilityid                  name     facilitytype  \
# 0           1   Sandy Beach Reserve  Park or reserve
# 1           2         Point Reserve  Park or reserve
# 2           3  Success Hill Reserve  Park or reserve
# 3           4       Jubilee Reserve  Park or reserve
# 4           5      Ashfield Reserve  Park or reserve
#
#                      address1        town state   latitude   longitude  \
# 0       Lost 15525, West Road  Bassendean    WA -31.921836  115.950206
# 1         Lot 197, North Road  Bassendean    WA -31.904410  115.960991
# 2    Lot 2838, Seventh Avenue  Bassendean    WA -31.896289  115.955781
# 3     Lot 6322, Robinson Road   Eden Hill    WA -31.891474  115.940164
# 4  Lot 12061, 2 Coulston Road    Ashfield    WA -31.913433  115.936477
#
#    parkingaccessible   male  female  unisex  allgender  accessible  \
# 0              False  False   False    True      False        True
# 1              False  False   False    True      False        True
# 2               True   True    True   False      False        True
# 3              False   True    True   False      False       False
# 4               True  False   False    True      False        True
#
#    paymentrequired  babychange
# 0            False        True
# 1            False        True
# 2            False        True
# 3            False       False
# 4            False        True

# %%
# Filtering to only VIC
toilet_df = toilet_df[toilet_df['state'] == 'VIC']

toilet_df.head(5)
# Out:
#      facilityid             name facilitytype            address1      town  \
# 181         252     Lloyd Street        Other        Lloyd Street  Dimboola
# 182         253     Lloyd Street  Bus station        Lloyd Street  Dimboola
# 183         254   Charles Street        Other      Charles Street   Jeparit
# 184         255       Roy Street        Other          Roy Street   Jeparit
# 185         256  Western Highway  Bus station  24 Victoria Street     Nhill
#
#     state   latitude   longitude  parkingaccessible  male  female  unisex  \
# 181   VIC -36.454567  142.026468              False  True    True   False
# 182   VIC -36.454121  142.026374              False  True    True   False
# 183   VIC -36.142494  141.988242              False  True    True   False
# 184   VIC -36.143049  141.987369              False  True    True   False
# 185   VIC -36.333924  141.649202              False  True    True   False
#
#      allgender  accessible  paymentrequired  babychange
# 181      False        True            False       False
# 182      False        True            False        True
# 183      False        True            False       False
# 184      False       False            False       False
# 185      False        True            False       False

# %%
# Standardising strings to lowercase
toilet_df = toilet_df.map(lambda x: x.lower() if isinstance(x, str) else x)

# Resetting index
toilet_df.reset_index(drop=True, inplace=True)

toilet_df.head(5)
# Out:
#    facilityid             name facilitytype            address1      town  \
# 0         252     lloyd street        other        lloyd street  dimboola
# 1         253     lloyd street  bus station        lloyd street  dimboola
# 2         254   charles street        other      charles street   jeparit
# 3         255       roy street        other          roy street   jeparit
# 4         256  western highway  bus station  24 victoria street     nhill
#
#   state   latitude   longitude  parkingaccessible  male  female  unisex  \
# 0   vic -36.454567  142.026468              False  True    True   False
# 1   vic -36.454121  142.026374              False  True    True   False
# 2   vic -36.142494  141.988242              False  True    True   False
# 3   vic -36.143049  141.987369              False  True    True   False
# 4   vic -36.333924  141.649202              False  True    True   False
#
#    allgender  accessible  paymentrequired  babychange
# 0      False        True            False       False
# 1      False        True            False        True
# 2      False        True            False       False
# 3      False       False            False       False
# 4      False        True            False       False

# %%
# Checking for duplicates
toilet_df[toilet_df[['name','facilitytype', 'latitude', 'longitude']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [facilityid, name, facilitytype, address1, town, state, latitude, longitude, parkingaccessible, male, female, unisex, allgender, accessible, paymentrequired, babychange]
# Index: []

# %%
toilet_df['facilitytype'].unique()
# Out:
# array(['other', 'bus station', 'park or reserve', 'sporting facility',
#        'car park', 'community building', 'beach', 'shopping centre',
#        'jetty', 'camping ground', 'airport', 'rest area', 'swimming pool',
#        'caravan park', 'train station', 'food outlet', 'cemetery',
#        'service station'], dtype=object)

# %%
# Flitering out Restaurants
toilet_df = toilet_df[toilet_df['facilitytype'] != 'food outlet']

# Renaming columns
toilet_df = toilet_df.rename(columns={'facilityid': 'Location_ID', 'address1': 'address', 'town': 'suburb',
                                      'latitude': 'Location_Lat', 'longitude': 'Location_Lon',
                                      'accessible': 'wheelchair', 'babychange': 'changing_table'})

toilet_df.head(5)
# Out:
#    Location_ID             name facilitytype             address    suburb  \
# 0          252     lloyd street        other        lloyd street  dimboola
# 1          253     lloyd street  bus station        lloyd street  dimboola
# 2          254   charles street        other      charles street   jeparit
# 3          255       roy street        other          roy street   jeparit
# 4          256  western highway  bus station  24 victoria street     nhill
#
#   state  Location_Lat  Location_Lon  parkingaccessible  male  female  unisex  \
# 0   vic    -36.454567    142.026468              False  True    True   False
# 1   vic    -36.454121    142.026374              False  True    True   False
# 2   vic    -36.142494    141.988242              False  True    True   False
# 3   vic    -36.143049    141.987369              False  True    True   False
# 4   vic    -36.333924    141.649202              False  True    True   False
#
#    allgender  wheelchair  paymentrequired  changing_table
# 0      False        True            False           False
# 1      False        True            False            True
# 2      False        True            False           False
# 3      False       False            False           False
# 4      False        True            False           False

# %%
# Standardising boolean values
bool_cols = toilet_df.columns[-8:]

for col in bool_cols:
    toilet_df[col] = toilet_df[col].map({True: 'yes', False: 'no'})

toilet_df.head(5)
# Out:
#    Location_ID             name facilitytype             address    suburb  \
# 0          252     lloyd street        other        lloyd street  dimboola
# 1          253     lloyd street  bus station        lloyd street  dimboola
# 2          254   charles street        other      charles street   jeparit
# 3          255       roy street        other          roy street   jeparit
# 4          256  western highway  bus station  24 victoria street     nhill
#
#   state  Location_Lat  Location_Lon parkingaccessible male female unisex  \
# 0   vic    -36.454567    142.026468                no  yes    yes     no
# 1   vic    -36.454121    142.026374                no  yes    yes     no
# 2   vic    -36.142494    141.988242                no  yes    yes     no
# 3   vic    -36.143049    141.987369                no  yes    yes     no
# 4   vic    -36.333924    141.649202                no  yes    yes     no
#
#   allgender wheelchair paymentrequired changing_table
# 0        no        yes              no             no
# 1        no        yes              no            yes
# 2        no        yes              no             no
# 3        no         no              no             no
# 4        no        yes              no             no

# %% [markdown]
# # Creating Final Table Structure

# %%
toilet_data = toilet_df

# Creating a column with dictionary of metadata
metadata_cols = ['name', 'facilitytype', 'address', 'suburb', 'state']
toilet_data['Metadata'] = toilet_data[metadata_cols].apply(lambda row: row.to_dict(), axis=1)

toilet_data.head(5)
# Out:
#    Location_ID             name facilitytype             address    suburb  \
# 0          252     lloyd street        other        lloyd street  dimboola
# 1          253     lloyd street  bus station        lloyd street  dimboola
# 2          254   charles street        other      charles street   jeparit
# 3          255       roy street        other          roy street   jeparit
# 4          256  western highway  bus station  24 victoria street     nhill
#
#   state  Location_Lat  Location_Lon parkingaccessible male female unisex  \
# 0   vic    -36.454567    142.026468                no  yes    yes     no
# 1   vic    -36.454121    142.026374                no  yes    yes     no
# 2   vic    -36.142494    141.988242                no  yes    yes     no
# 3   vic    -36.143049    141.987369                no  yes    yes     no
# 4   vic    -36.333924    141.649202                no  yes    yes     no
#
#   allgender wheelchair paymentrequired changing_table  \
# 0        no        yes              no             no
# 1        no        yes              no            yes
# 2        no        yes              no             no
# 3        no         no              no             no
# 4        no        yes              no             no
#
#                                             Metadata
# 0  {'name': 'lloyd street', 'facilitytype': 'othe...
# 1  {'name': 'lloyd street', 'facilitytype': 'bus ...
# 2  {'name': 'charles street', 'facilitytype': 'ot...
# 3  {'name': 'roy street', 'facilitytype': 'other'...
# 4  {'name': 'western highway', 'facilitytype': 'b...

# %%
# Creating a column with dictionary of tags
tags_cols = ['parkingaccessible', 'male', 'female', 'unisex', 'allgender', 'wheelchair', 'changing_table']
toilet_data['Tags'] = toilet_data[tags_cols].apply(lambda row: row.to_dict(), axis = 1)

# Adding a column for type of accessibility feature
toilet_data['Accesibility_Type_Name'] = 'toilets'

toilet_data.head(5)
# Out:
#    Location_ID             name facilitytype             address    suburb  \
# 0          252     lloyd street        other        lloyd street  dimboola
# 1          253     lloyd street  bus station        lloyd street  dimboola
# 2          254   charles street        other      charles street   jeparit
# 3          255       roy street        other          roy street   jeparit
# 4          256  western highway  bus station  24 victoria street     nhill
#
#   state  Location_Lat  Location_Lon parkingaccessible male female unisex  \
# 0   vic    -36.454567    142.026468                no  yes    yes     no
# 1   vic    -36.454121    142.026374                no  yes    yes     no
# 2   vic    -36.142494    141.988242                no  yes    yes     no
# 3   vic    -36.143049    141.987369                no  yes    yes     no
# 4   vic    -36.333924    141.649202                no  yes    yes     no
#
#   allgender wheelchair paymentrequired changing_table  \
# 0        no        yes              no             no
# 1        no        yes              no            yes
# 2        no        yes              no             no
# 3        no         no              no             no
# 4        no        yes              no             no
#
#                                             Metadata  \
# 0  {'name': 'lloyd street', 'facilitytype': 'othe...
# 1  {'name': 'lloyd street', 'facilitytype': 'bus ...
# 2  {'name': 'charles street', 'facilitytype': 'ot...
# 3  {'name': 'roy street', 'facilitytype': 'other'...
# 4  {'name': 'western highway', 'facilitytype': 'b...
#
#                                                 Tags Accesibility_Type_Name
# 0  {'parkingaccessible': 'no', 'male': 'yes', 'fe...                toilets
# 1  {'parkingaccessible': 'no', 'male': 'yes', 'fe...                toilets
# 2  {'parkingaccessible': 'no', 'male': 'yes', 'fe...                toilets
# 3  {'parkingaccessible': 'no', 'male': 'yes', 'fe...                toilets
# 4  {'parkingaccessible': 'no', 'male': 'yes', 'fe...                toilets

# %%
# Retrieving final table

toilet_data = toilet_data[['Location_ID', 'Location_Lat', 'Location_Lon', 'Accesibility_Type_Name',
                           'Metadata', 'Tags']]

toilet_data.head(5)
# Out:
#    Location_ID  Location_Lat  Location_Lon Accesibility_Type_Name  \
# 0          252    -36.454567    142.026468                toilets
# 1          253    -36.454121    142.026374                toilets
# 2          254    -36.142494    141.988242                toilets
# 3          255    -36.143049    141.987369                toilets
# 4          256    -36.333924    141.649202                toilets
#
#                                             Metadata  \
# 0  {'name': 'lloyd street', 'facilitytype': 'othe...
# 1  {'name': 'lloyd street', 'facilitytype': 'bus ...
# 2  {'name': 'charles street', 'facilitytype': 'ot...
# 3  {'name': 'roy street', 'facilitytype': 'other'...
# 4  {'name': 'western highway', 'facilitytype': 'b...
#
#                                                 Tags
# 0  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 1  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 2  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 3  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 4  {'parkingaccessible': 'no', 'male': 'yes', 'fe...

# %%
# Exporting data 
toilet_data.to_csv("toilets_CSV.csv", index=False)

# %% [markdown]
# # Combining OSM and Static data

# %%
import pandas as pd

toilet_static = pd.read_csv('toilets_CSV.csv')
toilet_osm = pd.read_csv('toilets_OSM.csv')

# Renaming column of toilet OSM data
toilet_static = toilet_static.rename(columns={'Accesibility_Type_Name':'Accessibility_Type_Name'})
toilet_osm = toilet_osm.rename(columns={'ACCESSIBILITY_TYPE_NAME': 'Accessibility_Type_Name'})

toilets_full = pd.concat([toilet_static, toilet_osm], axis=0)

toilets_full.head(5)
# Out:
#    Location_ID  Location_Lat  Location_Lon Accessibility_Type_Name  \
# 0          252    -36.454567    142.026468                 toilets
# 1          253    -36.454121    142.026374                 toilets
# 2          254    -36.142494    141.988242                 toilets
# 3          255    -36.143049    141.987369                 toilets
# 4          256    -36.333924    141.649202                 toilets
#
#                                             Metadata  \
# 0  {'name': 'lloyd street', 'facilitytype': 'othe...
# 1  {'name': 'lloyd street', 'facilitytype': 'bus ...
# 2  {'name': 'charles street', 'facilitytype': 'ot...
# 3  {'name': 'roy street', 'facilitytype': 'other'...
# 4  {'name': 'western highway', 'facilitytype': 'b...
#
#                                                 Tags
# 0  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 1  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 2  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 3  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 4  {'parkingaccessible': 'no', 'male': 'yes', 'fe...

# %%
# standardising lat and lon to 6 decimal places
toilets_full['Location_Lat'] = toilets_full['Location_Lat'].round(6)
toilets_full['Location_Lon'] = toilets_full['Location_Lon'].round(6)

toilets_full.head()
# Out:
#    Location_ID  Location_Lat  Location_Lon Accessibility_Type_Name  \
# 0          252    -36.454567    142.026468                 toilets
# 1          253    -36.454121    142.026374                 toilets
# 2          254    -36.142494    141.988242                 toilets
# 3          255    -36.143049    141.987369                 toilets
# 4          256    -36.333924    141.649202                 toilets
#
#                                             Metadata  \
# 0  {'name': 'lloyd street', 'facilitytype': 'othe...
# 1  {'name': 'lloyd street', 'facilitytype': 'bus ...
# 2  {'name': 'charles street', 'facilitytype': 'ot...
# 3  {'name': 'roy street', 'facilitytype': 'other'...
# 4  {'name': 'western highway', 'facilitytype': 'b...
#
#                                                 Tags
# 0  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 1  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 2  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 3  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 4  {'parkingaccessible': 'no', 'male': 'yes', 'fe...

# %% [markdown]
# Exact matching duplicates
# - Number of records counted as duplicates: 8

# %%
# Checking for duplicated data
# Check for duplicate rows based on both latitude and longitude
duplicates = toilets_full.duplicated(subset=['Location_Lat', 'Location_Lon'], keep=False)

# Show all duplicate rows (keeping all occurrences)
duplicate_rows = toilets_full[duplicates]
print(f"Found {len(duplicate_rows)} duplicate location entries")
duplicate_rows.sort_values(['Location_Lat', 'Location_Lon'])
# Out:
# Found 8 duplicate location entries
#       Location_ID  Location_Lat  Location_Lon Accessibility_Type_Name  \
# 5293        62142    -38.412562    144.189241                 toilets
# 5294        62143    -38.412562    144.189241                 toilets
# 5360        62501    -38.172926    145.927828                 toilets
# 5361        62502    -38.172926    145.927828                 toilets
# 3266        41747    -37.754995    142.008182                 toilets
# 115    4010647837    -37.754995    142.008182                 toilets
# 190          1423    -37.733013    142.039729                 toilets
# 132    4010648831    -37.733013    142.039729                 toilets
#
#                                                Metadata  \
# 5293  {'name': 'four kings ', 'facilitytype': 'beach...
# 5294  {'name': 'four kings changing place', 'facilit...
# 5360  {'name': 'west gippsland hospital - consulting...
# 5361  {'name': 'west gippsland hospital - emergency ...
# 3266  {'name': 'hamilton livestock exchange', 'facil...
# 115    {"operator": "southern grampians shire council"}
# 190   {'name': 'lake hamilton - boat ramp', 'facilit...
# 132    {"operator": "southern grampians shire council"}
#
#                                                    Tags
# 5293  {'parkingaccessible': 'yes', 'male': 'yes', 'f...
# 5294  {'parkingaccessible': 'yes', 'male': 'no', 'fe...
# 5360  {'parkingaccessible': 'yes', 'male': 'yes', 'f...
# 5361  {'parkingaccessible': 'yes', 'male': 'yes', 'f...
# 3266  {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 115   {"wheelchair": "no", "name": "hamilton - lives...
# 190   {'parkingaccessible': 'yes', 'male': 'yes', 'f...
# 132   {"wheelchair": "yes", "name": "hamilton - lake...

# %%
duplicate_rows.to_csv('toilets_test.csv')

# %%
duplicate_rows.count()
# Out:
# Location_ID                8
# Location_Lat               8
# Location_Lon               8
# Accessibility_Type_Name    8
# Metadata                   8
# Tags                       8
# dtype: int64

# %% [markdown]
# Rough Duplicates (if rounded up to 4 decimals)
# - Number of records counted as duplicates: 142

# %%
# Round coordinates to 4 decimal places (~11 meter precision)
toilets_full['rounded_lat'] = toilets_full['Location_Lat'].round(4)
toilets_full['rounded_lon'] = toilets_full['Location_Lon'].round(4)

# Check for duplicates on rounded coordinates
fuzzy_duplicates = toilets_full.duplicated(subset=['rounded_lat', 'rounded_lon'], keep=False)

# Count how many times each location appears
location_counts = toilets_full.groupby(['rounded_lat', 'rounded_lon']).size().reset_index(name='count')
duplicate_counts = location_counts[location_counts['count'] > 1]

duplicate_counts
# Out:
#       rounded_lat  rounded_lon  count
# 58       -38.7594     143.6717      2
# 67       -38.7399     143.6749      2
# 81       -38.6935     146.0823      2
# 102      -38.6621     143.1054      2
# 116      -38.6416     145.7147      2
# ...           ...          ...    ...
# 6245     -35.1363     142.0252      2
# 6257     -35.0691     142.3154      2
# 6345     -34.3909     141.5947      2
# 6418     -34.1807     142.1640      2
# 6433     -34.1650     142.0548      2
#
# [142 rows x 3 columns]

# %% [markdown]
# 20 Meter threshold
# - Number of records detected as duplicates: 291

# %%
import pandas as pd
import numpy as np

def flag_nearby_duplicates(toilets_df, lat_col='Location_Lat', lon_col='Location_Lon', threshold_meters=20):
    # Calculate precision needed (~0.0002 degrees ≈ 20 meters)
    precision = int(np.ceil(-np.log10(threshold_meters/111000)))
    
    # Create rounded coordinates for grouping
    toilets_df = toilets_df.copy()
    toilets_df['coord_group'] = (
        toilets_df[lat_col].round(precision).astype(str) + "|" + 
        toilets_df[lon_col].round(precision).astype(str)
    )
    
    # Calculate group stats
    group_stats = toilets_df.groupby('coord_group').agg({
        lat_col: 'first',
        lon_col: 'first',
        'coord_group': 'size'
    }).rename(columns={'coord_group': 'nearby_count'})
    
    # Only keep groups with duplicates
    duplicate_groups = group_stats[group_stats['nearby_count'] > 1]
    
    # Merge back with original data
    result = toilets_df.merge(
        duplicate_groups, 
        on='coord_group',
        how='left',
        suffixes=('', '_ref')
    )
    
    # Clean up columns
    result['duplicate_group'] = result.groupby('coord_group').ngroup()
    result.loc[result['nearby_count'].isna(), 'duplicate_group'] = np.nan
    
    # Rename reference columns
    result = result.rename(columns={
        f'{lat_col}_ref': 'reference_lat',
        f'{lon_col}_ref': 'reference_lon'
    })
    
    # Remove temporary column
    result = result.drop(columns=['coord_group'])
    
    return result

# Usage
marked_toilets = flag_nearby_duplicates(toilets_full)

# Show only the duplicates (optional)
marked_toilets[marked_toilets['duplicate_group'].notna()].sort_values('duplicate_group')
# Out:
#       Location_ID  Location_Lat  Location_Lon Accessibility_Type_Name  \
# 4892        61061    -34.165007    142.054815                 toilets
# 232          1725    -34.165025    142.054790                 toilets
# 6585   4936339521    -34.180739    142.163978                 toilets
# 213          1704    -34.180746    142.163986                 toilets
# 5302        62175    -34.390857    141.594673                 toilets
# ...           ...           ...           ...                     ...
# 5753   5913251715    -38.693482    146.082283                 toilets
# 5662  11843900525    -38.739946    143.674887                 toilets
# 5663  11843900526    -38.739899    143.674917                 toilets
# 5659   2484556678    -38.759397    143.671667                 toilets
# 2105        12826    -38.759415    143.671734                 toilets
#
#                                                Metadata  \
# 4892  {'name': 'kenny park', 'facilitytype': 'park o...
# 232   {'name': 'kenny park 2', 'facilitytype': 'park...
# 6585                                                 {}
# 213   {'name': 'jaycee park', 'facilitytype': 'park ...
# 5302  {'name': 'werrimull public hall', 'facilitytyp...
# ...                                                 ...
# 5753                                                 {}
# 5662                                                 {}
# 5663                                                 {}
# 5659                       {"check_date": "2023-10-30"}
# 2105  {'name': 'great ocean road', 'facilitytype': '...
#
#                                                    Tags  rounded_lat  \
# 4892  {'parkingaccessible': 'no', 'male': 'yes', 'fe...     -34.1650
# 232   {'parkingaccessible': 'yes', 'male': 'yes', 'f...     -34.1650
# 6585                 {"fee": "no", "wheelchair": "yes"}     -34.1807
# 213   {'parkingaccessible': 'yes', 'male': 'yes', 'f...     -34.1807
# 5302  {'parkingaccessible': 'no', 'male': 'yes', 'fe...     -34.3909
# ...                                                 ...          ...
# 5753                 {"fee": "no", "wheelchair": "yes"}     -38.6935
# 5662  {"access": "customers", "male": "yes", "wheelc...     -38.7399
# 5663  {"access": "customers", "female": "yes", "whee...     -38.7399
# 5659                  {"fee": "no", "wheelchair": "no"}     -38.7594
# 2105  {'parkingaccessible': 'no', 'male': 'yes', 'fe...     -38.7594
#
#       rounded_lon  reference_lat  reference_lon  nearby_count  duplicate_group
# 4892     142.0548     -34.165025     142.054790           2.0             15.0
# 232      142.0548     -34.165025     142.054790           2.0             15.0
# 6585     142.1640     -34.180746     142.163986           2.0             30.0
# 213      142.1640     -34.180746     142.163986           2.0             30.0
# 5302     141.5947     -34.390857     141.594673           2.0            102.0
# ...           ...            ...            ...           ...              ...
# 5753     146.0823     -38.693512     146.082261           2.0           6367.0
# 5662     143.6749     -38.739946     143.674887           2.0           6381.0
# 5663     143.6749     -38.739946     143.674887           2.0           6381.0
# 5659     143.6717     -38.759415     143.671734           2.0           6390.0
# 2105     143.6717     -38.759415     143.671734           2.0           6390.0
#
# [291 rows x 12 columns]

# %%
def remove_duplicates_keep_one(toilets_df, lat_col='Location_Lat', lon_col='Location_Lon', threshold_meters=20):
    """
    Removes nearby duplicates (keeping one per group) while preserving all unique records.
    
    Returns:
    - DataFrame with only one record per duplicate group (plus all non-duplicated records)
    """
    # First flag all duplicates
    marked_df = flag_nearby_duplicates(toilets_df, lat_col, lon_col, threshold_meters)
    
    # For duplicate groups, keep the first record; always keep non-duplicates
    deduped_df = marked_df[~marked_df['duplicate_group'].notna() | 
                           (marked_df['duplicate_group'].notna() & 
                            (marked_df.groupby('duplicate_group').cumcount() == 0))]
    
    return deduped_df

# Usage
deduped_toilets = remove_duplicates_keep_one(toilets_full)

len(deduped_toilets)
# Out:
# 6449

# %%
final_toilets = deduped_toilets[['Location_Lat', 'Location_Lon', 'Accessibility_Type_Name',
                                 'Metadata', 'Tags']]

final_toilets
# Out:
#       Location_Lat  Location_Lon Accessibility_Type_Name  \
# 0       -36.454567    142.026468                 toilets
# 1       -36.454121    142.026374                 toilets
# 2       -36.142494    141.988242                 toilets
# 3       -36.143049    141.987369                 toilets
# 4       -36.333924    141.649202                 toilets
# ...            ...           ...                     ...
# 6593    -33.922352    147.199795                 toilets
# 6594    -33.924102    147.234089                 toilets
# 6595    -33.906437    148.160552                 toilets
# 6596    -34.167363    148.458657                 toilets
# 6597    -34.039296    148.555930                 toilets
#
#                                                Metadata  \
# 0     {'name': 'lloyd street', 'facilitytype': 'othe...
# 1     {'name': 'lloyd street', 'facilitytype': 'bus ...
# 2     {'name': 'charles street', 'facilitytype': 'ot...
# 3     {'name': 'roy street', 'facilitytype': 'other'...
# 4     {'name': 'western highway', 'facilitytype': 'b...
# ...                                                 ...
# 6593                                                 {}
# 6594                                                 {}
# 6595               {"operator": "Weddin Shire Council"}
# 6596                                                 {}
# 6597                                                 {}
#
#                                                    Tags
# 0     {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 1     {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 2     {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 3     {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# 4     {'parkingaccessible': 'no', 'male': 'yes', 'fe...
# ...                                                 ...
# 6593  {"access": "yes", "disposal": "flush", "wheelc...
# 6594  {"access": "yes", "disposal": "flush", "wheelc...
# 6595  {"access": "yes", "fee": "no", "female": "yes"...
# 6596  {"access": "yes", "fee": "no", "disposal": "fl...
# 6597  {"access": "yes", "disposal": "flush", "wheelc...
#
# [6449 rows x 5 columns]

# %%
import ast

def safe_parse_dict(val):
    if isinstance(val, str) and val.strip().startswith('{') and val.strip().endswith('}'):
        try:
            return ast.literal_eval(val)
        except (ValueError, SyntaxError):
            return {}  # fallback in case it's not valid
    return val if isinstance(val, dict) else {}

final_toilets['Metadata'] = final_toilets['Metadata'].apply(safe_parse_dict)
final_toilets['Tags'] = final_toilets['Tags'].apply(safe_parse_dict)
# Out:
# /var/folders/1c/9fnl9hf9303_47zn3q64zv9c0000gn/T/ipykernel_35877/1223028769.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_toilets['Metadata'] = final_toilets['Metadata'].apply(safe_parse_dict)
# /var/folders/1c/9fnl9hf9303_47zn3q64zv9c0000gn/T/ipykernel_35877/1223028769.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_toilets['Tags'] = final_toilets['Tags'].apply(safe_parse_dict)

# %%
final_toilets.to_json('final_toilets.json', orient='records', indent=2)
